# %%
#This code uses 3D Unet to train a network on 3D subvolumes (64x64x64).
#It also segments a large volume and outputs a multidimensional OMETIFF file
#Custom dataset is used for this code but it should work on any dataset, including BRATS.

# %%
#Latest Tensorflow (2.4) is giving error for some of the libraries we will be using, 
# especially segmentation models 3D. 
# The default working TF version is 1.x. 
#But i have made chanes to work with 2.x. 
#If you have your own 3D unet model, you can try the latest TF version.

# %%
#Install all dependencies for sgementation-models-3D library.
#We will use this library to call 3D unet.
#Alternative, you can define your own Unet, if you have skills!
# !git clone https://github.com/talhaanwarch/3D_segmentation_TF2
# Out:
# Cloning into '3D_segmentation_TF2'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 89 (delta 17), reused 89 (delta 17), pack-reused 0
# Unpacking objects: 100% (89/89), done.

# %%
#Use patchify to break large volumes into smaller for training 
#and also to put patches back together after prediction.
# %%capture
# !pip install patchify
# !pip install tensorflow==2.1.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
#Make sure the GPU is available. 
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#add the path of package 
import sys
sys.path.append('/content/3D_segmentation_TF2')

# %%
import segmentation_models_3D as sm
# Out:
# layers <module 'tensorflow_core.python.keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/api/_v2/keras/layers/__init__.py'>
# Segmentation Models: using `tf.keras` framework.

# %%
from skimage import io
from patchify import patchify, unpatchify
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split

# %%
#download the data from google drive
import gdown
url = 'https://drive.google.com/u/0/uc?id=1HWtBaSa-LTyAMgf2uaz1T9o1sTWDBajU'
output = 'sandstone_data_for_ML.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1HWtBaSa-LTyAMgf2uaz1T9o1sTWDBajU
# To: /content/sandstone_data_for_ML.zip
# 450MB [00:02, 210MB/s]
# 'sandstone_data_for_ML.zip'

# %%
# %%capture
#unzip data
# !unzip 'sandstone_data_for_ML.zip'

# %%
#Load input images and masks. 
#Here we load 256x256x256 pixel volume. We will break it into patches of 64x64x64 for training. 
image = io.imread('/content/sandstone_data_for_ML/data_for_3D_Unet/train_images_256_256_256.tif')
img_patches = patchify(image, (64, 64, 64), step=64)  #Step=64 for 64 patches means no overlap

mask = io.imread('/content/sandstone_data_for_ML/data_for_3D_Unet/train_masks_256_256_256.tif')
mask_patches = patchify(mask, (64, 64, 64), step=64)

# %%
plt.imshow(img_patches[1,2,3,:,:,32],cmap='gray')
#plt.imshow(mask_patches[1,2,3,:,:,32])

# %%
input_img = np.reshape(img_patches, (-1, img_patches.shape[3], img_patches.shape[4], img_patches.shape[5]))
input_mask = np.reshape(mask_patches, (-1, mask_patches.shape[3], mask_patches.shape[4], mask_patches.shape[5]))

print(input_img.shape)  # n_patches, x, y, z
# Out:
# (64, 64, 64, 64)

# %%
n_classes=4

# %%
#Convert grey image to 3 channels by copying channel 3 times.
#We do this as our unet model expects 3 channel input. 

train_img = np.stack((input_img,)*3, axis=-1)
train_mask = np.expand_dims(input_mask, axis=4)


train_mask_cat = to_categorical(train_mask, num_classes=n_classes)


X_train, X_test, y_train, y_test = train_test_split(train_img, train_mask_cat, test_size = 0.10, random_state = 0)

# %%
# Loss Function and coefficients to be used during training:
def dice_coefficient(y_true, y_pred):
    smoothing_factor = 1
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    return (2. * K.sum(flat_y_true * flat_y_pred) + smoothing_factor) / (K.sum(flat_y_true) + K.sum(flat_y_pred) + smoothing_factor)

def dice_coefficient_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# %% [markdown]
# Backbones: ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'seresnet18', 'seresnet34', 'seresnet50', 'seresnet101', 'seresnet152', 'seresnext50', 'seresnext101', 'senet154', 'resnext50', 'resnext101', 'vgg16', 'vgg19', 'densenet121', 'densenet169', 'densenet201', 'inceptionresnetv2', 'inceptionv3', 'mobilenet', 'mobilenetv2', 'efficientnetb0', 'efficientnetb1', 'efficientnetb2', 'efficientnetb3', 'efficientnetb4', 'efficientnetb5', 'efficientnetb6', 'efficientnetb7']

# %%
#Define parameters for our model.

encoder_weights = 'imagenet'
BACKBONE = 'vgg16'  #Try vgg16, efficientnetb7, inceptionv3, resnet50
activation = 'softmax'
patch_size = 64
n_classes = 4
channels=3

LR = 0.0001
optim = optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([0.25, 0.25, 0.25, 0.25])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# %%
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
#Preprocess input data - otherwise you end up with garbage resutls 
# and potentially model that does not converge.
X_train_prep = preprocess_input(X_train)
X_test_prep = preprocess_input(X_test)

# %%
#Define the model. Here we use Unet but we can also use other model architectures from the library.
model = sm.Unet(BACKBONE, classes=n_classes, 
                input_shape=(patch_size, patch_size, patch_size, channels), 
                encoder_weights=encoder_weights,
                activation=activation)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())
# Out:
# kwargs {'classes': 4, 'input_shape': (64, 64, 64, 3), 'encoder_weights': 'imagenet', 'activation': 'softmax', 'backend': <module 'tensorflow_core.python.keras.api._v2.keras.backend' from '/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/api/_v2/keras/backend/__init__.py'>, 'layers': <module 'tensorflow_core.python.keras.api._v2.keras.layers' from '/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/api/_v2/keras/layers/__init__.py'>, 'models': <module 'tensorflow_core.python.keras.api._v2.keras.models' from '/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/api/_v2/keras/models/__init__.py'>, 'utils': <module 'tensorflow_core.python.keras.api._v2.keras.utils' from '/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/api/_v2/keras/utils/__init__.py'>}
# Downloading data from https://github.com/ZFTurbo/classification_models_3D/releases/download/v1.0/vgg16_inp_channel_3_tch_0_top_False.h5
# 176611328/176605248 [==============================] - 3s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 64,  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv3D)           (None, 64, 64, 64, 6 5248        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv3D)           (None, 64, 64, 64, 6 110656      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling3D)      (None, 32, 32, 32, 6 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv3D)           (None, 32, 32, 32, 1 221312      block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv3D)           (None, 32, 32, 32, 1 442496      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling3D)      (None, 16, 16, 16, 1 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv3D)           (None, 16, 16, 16, 2 884992      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv3D)           (None, 16, 16, 16, 2 1769728     block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv3D)           (None, 16, 16, 16, 2 1769728     block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling3D)      (None, 8, 8, 8, 256) 0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv3D)           (None, 8, 8, 8, 512) 3539456     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv3D)           (None, 8, 8, 8, 512) 7078400     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv3D)           (None, 8, 8, 8, 512) 7078400     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling3D)      (None, 4, 4, 4, 512) 0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv3D)           (None, 4, 4, 4, 512) 7078400     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv3D)           (None, 4, 4, 4, 512) 7078400     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv3D)           (None, 4, 4, 4, 512) 7078400     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling3D)      (None, 2, 2, 2, 512) 0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# center_block1_conv (Conv3D)     (None, 2, 2, 2, 512) 7077888     block5_pool[0][0]
# __________________________________________________________________________________________________
# center_block1_bn (BatchNormaliz (None, 2, 2, 2, 512) 2048        center_block1_conv[0][0]
# __________________________________________________________________________________________________
# center_block1_relu (Activation) (None, 2, 2, 2, 512) 0           center_block1_bn[0][0]
# __________________________________________________________________________________________________
# center_block2_conv (Conv3D)     (None, 2, 2, 2, 512) 7077888     center_block1_relu[0][0]
# __________________________________________________________________________________________________
# center_block2_bn (BatchNormaliz (None, 2, 2, 2, 512) 2048        center_block2_conv[0][0]
# __________________________________________________________________________________________________
# center_block2_relu (Activation) (None, 2, 2, 2, 512) 0           center_block2_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 4, 4, 4, 512) 0           center_block2_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 4, 4, 4, 1024 0           decoder_stage0_upsampling[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv3D)   (None, 4, 4, 4, 256) 7077888     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 4, 4, 4, 256) 1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 4, 4, 4, 256) 0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv3D)   (None, 4, 4, 4, 256) 1769472     decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 4, 4, 4, 256) 1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 4, 4, 4, 256) 0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 8, 8, 8, 256) 0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 8, 8, 8, 768) 0           decoder_stage1_upsampling[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv3D)   (None, 8, 8, 8, 128) 2654208     decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 8, 8, 8, 128) 512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 8, 8, 8, 128) 0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv3D)   (None, 8, 8, 8, 128) 442368      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 8, 8, 8, 128) 512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 8, 8, 8, 128) 0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 16, 16, 16, 1 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 16, 16, 16, 3 0           decoder_stage2_upsampling[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv3D)   (None, 16, 16, 16, 6 663552      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 16, 16, 16, 6 256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 16, 16, 16, 6 0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv3D)   (None, 16, 16, 16, 6 110592      decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 16, 16, 16, 6 256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 16, 16, 16, 6 0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 32, 32, 32, 6 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 32, 32, 32, 1 0           decoder_stage3_upsampling[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv3D)   (None, 32, 32, 32, 3 165888      decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 32, 32, 32, 3 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 32, 32, 32, 3 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv3D)   (None, 32, 32, 32, 3 27648       decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 32, 32, 32, 3 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 32, 32, 32, 3 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 64, 64, 64, 3 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv3D)   (None, 64, 64, 64, 1 13824       decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 64, 64, 64, 1 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 64, 64, 64, 1 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv3D)   (None, 64, 64, 64, 1 6912        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 64, 64, 64, 1 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 64, 64, 64, 1 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv3D)             (None, 64, 64, 64, 4 1732        decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 64, 64, 64, 4 0           final_conv[0][0]
# ==================================================================================================
# Total params: 71,233,540
# Trainable params: 71,229,508
# Non-trainable params: 4,032
# __________________________________________________________________________________________________
# None

# %%
#Fit the model
history=model.fit(X_train_prep, 
          y_train,
          batch_size=8, 
          epochs=100,
          verbose=1,
          validation_data=(X_test_prep, y_test))
# Out:
# Train on 57 samples, validate on 7 samples
# Epoch 1/100
# 57/57 [==============================] - 43s 749ms/sample - loss: 1.0098 - iou_score: 0.1170 - f1-score: 0.1824 - val_loss: 1.5542 - val_iou_score: 0.0522 - val_f1-score: 0.0946
# Epoch 2/100
# 57/57 [==============================] - 13s 233ms/sample - loss: 0.9738 - iou_score: 0.2215 - f1-score: 0.3117 - val_loss: 1.3313 - val_iou_score: 0.0823 - val_f1-score: 0.1417
# Epoch 3/100
# 57/57 [==============================] - 13s 237ms/sample - loss: 0.9549 - iou_score: 0.3370 - f1-score: 0.4668 - val_loss: 1.1709 - val_iou_score: 0.1192 - val_f1-score: 0.1928
# Epoch 4/100
# 57/57 [==============================] - 14s 241ms/sample - loss: 0.9391 - iou_score: 0.4372 - f1-score: 0.5825 - val_loss: 1.0869 - val_iou_score: 0.1350 - val_f1-score: 0.2178
# Epoch 5/100
# 57/57 [==============================] - 14s 242ms/sample - loss: 0.9296 - iou_score: 0.4662 - f1-score: 0.6114 - val_loss: 1.0797 - val_iou_score: 0.1338 - val_f1-score: 0.2155
# Epoch 6/100
# 57/57 [==============================] - 14s 243ms/sample - loss: 0.9198 - iou_score: 0.5022 - f1-score: 0.6433 - val_loss: 1.0406 - val_iou_score: 0.1560 - val_f1-score: 0.2454
# Epoch 7/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.9135 - iou_score: 0.5026 - f1-score: 0.6411 - val_loss: 1.0121 - val_iou_score: 0.2121 - val_f1-score: 0.3265
# Epoch 8/100
# 57/57 [==============================] - 14s 251ms/sample - loss: 0.9025 - iou_score: 0.5679 - f1-score: 0.7073 - val_loss: 0.9675 - val_iou_score: 0.2898 - val_f1-score: 0.4318
# Epoch 9/100
# 57/57 [==============================] - 14s 249ms/sample - loss: 0.8950 - iou_score: 0.5814 - f1-score: 0.7054 - val_loss: 0.9545 - val_iou_score: 0.3703 - val_f1-score: 0.5324
# Epoch 10/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8896 - iou_score: 0.6007 - f1-score: 0.7286 - val_loss: 0.9327 - val_iou_score: 0.4378 - val_f1-score: 0.5988
# Epoch 11/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8844 - iou_score: 0.6048 - f1-score: 0.7225 - val_loss: 0.9315 - val_iou_score: 0.5005 - val_f1-score: 0.6616
# Epoch 12/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8811 - iou_score: 0.6064 - f1-score: 0.7280 - val_loss: 0.9180 - val_iou_score: 0.5456 - val_f1-score: 0.6987
# Epoch 13/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8760 - iou_score: 0.6165 - f1-score: 0.7311 - val_loss: 0.9254 - val_iou_score: 0.4897 - val_f1-score: 0.6402
# Epoch 14/100
# 57/57 [==============================] - 14s 248ms/sample - loss: 0.8718 - iou_score: 0.6279 - f1-score: 0.7474 - val_loss: 0.9019 - val_iou_score: 0.6254 - val_f1-score: 0.7557
# Epoch 15/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8690 - iou_score: 0.6251 - f1-score: 0.7371 - val_loss: 0.9014 - val_iou_score: 0.6353 - val_f1-score: 0.7668
# Epoch 16/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8640 - iou_score: 0.6439 - f1-score: 0.7616 - val_loss: 0.8920 - val_iou_score: 0.6609 - val_f1-score: 0.7832
# Epoch 17/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8600 - iou_score: 0.6561 - f1-score: 0.7700 - val_loss: 0.8884 - val_iou_score: 0.6804 - val_f1-score: 0.7976
# Epoch 18/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8560 - iou_score: 0.6598 - f1-score: 0.7722 - val_loss: 0.8894 - val_iou_score: 0.6467 - val_f1-score: 0.7737
# Epoch 19/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8512 - iou_score: 0.6725 - f1-score: 0.7845 - val_loss: 0.8816 - val_iou_score: 0.7162 - val_f1-score: 0.8209
# Epoch 20/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8496 - iou_score: 0.6635 - f1-score: 0.7678 - val_loss: 0.8894 - val_iou_score: 0.6111 - val_f1-score: 0.7401
# Epoch 21/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8478 - iou_score: 0.6808 - f1-score: 0.7903 - val_loss: 0.8811 - val_iou_score: 0.6742 - val_f1-score: 0.7794
# Epoch 22/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8460 - iou_score: 0.6784 - f1-score: 0.7882 - val_loss: 0.8794 - val_iou_score: 0.6916 - val_f1-score: 0.8063
# Epoch 23/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8444 - iou_score: 0.6744 - f1-score: 0.7850 - val_loss: 0.8647 - val_iou_score: 0.7342 - val_f1-score: 0.8352
# Epoch 24/100
# 57/57 [==============================] - 14s 247ms/sample - loss: 0.8389 - iou_score: 0.6914 - f1-score: 0.7997 - val_loss: 0.8591 - val_iou_score: 0.7019 - val_f1-score: 0.8100
# Epoch 25/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8384 - iou_score: 0.6797 - f1-score: 0.7876 - val_loss: 0.8580 - val_iou_score: 0.6944 - val_f1-score: 0.8016
# Epoch 26/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8386 - iou_score: 0.6829 - f1-score: 0.7907 - val_loss: 0.8631 - val_iou_score: 0.7043 - val_f1-score: 0.8068
# Epoch 27/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8350 - iou_score: 0.6979 - f1-score: 0.8034 - val_loss: 0.8528 - val_iou_score: 0.7041 - val_f1-score: 0.8078
# Epoch 28/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8303 - iou_score: 0.7134 - f1-score: 0.8193 - val_loss: 0.8494 - val_iou_score: 0.7084 - val_f1-score: 0.8112
# Epoch 29/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8309 - iou_score: 0.6855 - f1-score: 0.7896 - val_loss: 0.8469 - val_iou_score: 0.7296 - val_f1-score: 0.8292
# Epoch 30/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8297 - iou_score: 0.7003 - f1-score: 0.8065 - val_loss: 0.8421 - val_iou_score: 0.7390 - val_f1-score: 0.8354
# Epoch 31/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8250 - iou_score: 0.7049 - f1-score: 0.8090 - val_loss: 0.8386 - val_iou_score: 0.7356 - val_f1-score: 0.8335
# Epoch 32/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8260 - iou_score: 0.7101 - f1-score: 0.8132 - val_loss: 0.8374 - val_iou_score: 0.7348 - val_f1-score: 0.8362
# Epoch 33/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8185 - iou_score: 0.7250 - f1-score: 0.8262 - val_loss: 0.8321 - val_iou_score: 0.7457 - val_f1-score: 0.8431
# Epoch 34/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8200 - iou_score: 0.7041 - f1-score: 0.8070 - val_loss: 0.8347 - val_iou_score: 0.7156 - val_f1-score: 0.8165
# Epoch 35/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8157 - iou_score: 0.7076 - f1-score: 0.8030 - val_loss: 0.8273 - val_iou_score: 0.7473 - val_f1-score: 0.8447
# Epoch 36/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8163 - iou_score: 0.7016 - f1-score: 0.7948 - val_loss: 0.8279 - val_iou_score: 0.7235 - val_f1-score: 0.8268
# Epoch 37/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8148 - iou_score: 0.7233 - f1-score: 0.8242 - val_loss: 0.8250 - val_iou_score: 0.7323 - val_f1-score: 0.8324
# Epoch 38/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8217 - iou_score: 0.7022 - f1-score: 0.8086 - val_loss: 0.8241 - val_iou_score: 0.7330 - val_f1-score: 0.8357
# Epoch 39/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8137 - iou_score: 0.7245 - f1-score: 0.8236 - val_loss: 0.8165 - val_iou_score: 0.7559 - val_f1-score: 0.8495
# Epoch 40/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8137 - iou_score: 0.7280 - f1-score: 0.8287 - val_loss: 0.8190 - val_iou_score: 0.7260 - val_f1-score: 0.8254
# Epoch 41/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8098 - iou_score: 0.7471 - f1-score: 0.8431 - val_loss: 0.8242 - val_iou_score: 0.6993 - val_f1-score: 0.8099
# Epoch 42/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8090 - iou_score: 0.7538 - f1-score: 0.8487 - val_loss: 0.8125 - val_iou_score: 0.7575 - val_f1-score: 0.8512
# Epoch 43/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8085 - iou_score: 0.7431 - f1-score: 0.8400 - val_loss: 0.8244 - val_iou_score: 0.6980 - val_f1-score: 0.7966
# Epoch 44/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8083 - iou_score: 0.7514 - f1-score: 0.8456 - val_loss: 0.8243 - val_iou_score: 0.6937 - val_f1-score: 0.8060
# Epoch 45/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8113 - iou_score: 0.7306 - f1-score: 0.8301 - val_loss: 0.8176 - val_iou_score: 0.7144 - val_f1-score: 0.8173
# Epoch 46/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8142 - iou_score: 0.7162 - f1-score: 0.8145 - val_loss: 0.8226 - val_iou_score: 0.7018 - val_f1-score: 0.7965
# Epoch 47/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8078 - iou_score: 0.7448 - f1-score: 0.8399 - val_loss: 0.8164 - val_iou_score: 0.7158 - val_f1-score: 0.8173
# Epoch 48/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8073 - iou_score: 0.7524 - f1-score: 0.8441 - val_loss: 0.8159 - val_iou_score: 0.7124 - val_f1-score: 0.8199
# Epoch 49/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8059 - iou_score: 0.7512 - f1-score: 0.8470 - val_loss: 0.8176 - val_iou_score: 0.7034 - val_f1-score: 0.8125
# Epoch 50/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8108 - iou_score: 0.7181 - f1-score: 0.8198 - val_loss: 0.8297 - val_iou_score: 0.6487 - val_f1-score: 0.7717
# Epoch 51/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8079 - iou_score: 0.7345 - f1-score: 0.8321 - val_loss: 0.8196 - val_iou_score: 0.6966 - val_f1-score: 0.8002
# Epoch 52/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8066 - iou_score: 0.7273 - f1-score: 0.8196 - val_loss: 0.8062 - val_iou_score: 0.7505 - val_f1-score: 0.8432
# Epoch 53/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8044 - iou_score: 0.7437 - f1-score: 0.8392 - val_loss: 0.8388 - val_iou_score: 0.6246 - val_f1-score: 0.7428
# Epoch 54/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8065 - iou_score: 0.7379 - f1-score: 0.8353 - val_loss: 0.8115 - val_iou_score: 0.7187 - val_f1-score: 0.8223
# Epoch 55/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8070 - iou_score: 0.7310 - f1-score: 0.8263 - val_loss: 0.8146 - val_iou_score: 0.7092 - val_f1-score: 0.8167
# Epoch 56/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8042 - iou_score: 0.7361 - f1-score: 0.8348 - val_loss: 0.8146 - val_iou_score: 0.7146 - val_f1-score: 0.8100
# Epoch 57/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8025 - iou_score: 0.7549 - f1-score: 0.8492 - val_loss: 0.8136 - val_iou_score: 0.7124 - val_f1-score: 0.8169
# Epoch 58/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8009 - iou_score: 0.7605 - f1-score: 0.8538 - val_loss: 0.8154 - val_iou_score: 0.7092 - val_f1-score: 0.8148
# Epoch 59/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8018 - iou_score: 0.7409 - f1-score: 0.8294 - val_loss: 0.8176 - val_iou_score: 0.7011 - val_f1-score: 0.8018
# Epoch 60/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8020 - iou_score: 0.7596 - f1-score: 0.8501 - val_loss: 0.8096 - val_iou_score: 0.7255 - val_f1-score: 0.8303
# Epoch 61/100
# 57/57 [==============================] - 14s 246ms/sample - loss: 0.8059 - iou_score: 0.7449 - f1-score: 0.8382 - val_loss: 0.8124 - val_iou_score: 0.7216 - val_f1-score: 0.8198
# Epoch 62/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7984 - iou_score: 0.7761 - f1-score: 0.8655 - val_loss: 0.8187 - val_iou_score: 0.6889 - val_f1-score: 0.8021
# Epoch 63/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8025 - iou_score: 0.7523 - f1-score: 0.8465 - val_loss: 0.8154 - val_iou_score: 0.7089 - val_f1-score: 0.8091
# Epoch 64/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.8002 - iou_score: 0.7672 - f1-score: 0.8563 - val_loss: 0.8190 - val_iou_score: 0.6922 - val_f1-score: 0.8004
# Epoch 65/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7992 - iou_score: 0.7711 - f1-score: 0.8582 - val_loss: 0.8203 - val_iou_score: 0.6864 - val_f1-score: 0.7974
# Epoch 66/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7958 - iou_score: 0.7829 - f1-score: 0.8694 - val_loss: 0.8105 - val_iou_score: 0.7256 - val_f1-score: 0.8261
# Epoch 67/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7959 - iou_score: 0.7596 - f1-score: 0.8452 - val_loss: 0.8083 - val_iou_score: 0.7317 - val_f1-score: 0.8350
# Epoch 68/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7980 - iou_score: 0.7730 - f1-score: 0.8618 - val_loss: 0.8098 - val_iou_score: 0.7232 - val_f1-score: 0.8254
# Epoch 69/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7984 - iou_score: 0.7652 - f1-score: 0.8532 - val_loss: 0.8094 - val_iou_score: 0.7277 - val_f1-score: 0.8290
# Epoch 70/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7975 - iou_score: 0.7688 - f1-score: 0.8584 - val_loss: 0.8108 - val_iou_score: 0.7221 - val_f1-score: 0.8253
# Epoch 71/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7950 - iou_score: 0.7613 - f1-score: 0.8496 - val_loss: 0.8094 - val_iou_score: 0.7330 - val_f1-score: 0.8285
# Epoch 72/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7968 - iou_score: 0.7701 - f1-score: 0.8591 - val_loss: 0.8047 - val_iou_score: 0.7491 - val_f1-score: 0.8468
# Epoch 73/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7927 - iou_score: 0.7890 - f1-score: 0.8738 - val_loss: 0.8120 - val_iou_score: 0.7193 - val_f1-score: 0.8202
# Epoch 74/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7925 - iou_score: 0.7687 - f1-score: 0.8492 - val_loss: 0.8194 - val_iou_score: 0.6924 - val_f1-score: 0.7982
# Epoch 75/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7952 - iou_score: 0.7811 - f1-score: 0.8688 - val_loss: 0.8087 - val_iou_score: 0.7295 - val_f1-score: 0.8324
# Epoch 76/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7946 - iou_score: 0.7853 - f1-score: 0.8725 - val_loss: 0.8068 - val_iou_score: 0.7383 - val_f1-score: 0.8338
# Epoch 77/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7941 - iou_score: 0.7793 - f1-score: 0.8636 - val_loss: 0.8068 - val_iou_score: 0.7359 - val_f1-score: 0.8369
# Epoch 78/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7926 - iou_score: 0.7942 - f1-score: 0.8766 - val_loss: 0.8091 - val_iou_score: 0.7319 - val_f1-score: 0.8276
# Epoch 79/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7935 - iou_score: 0.7666 - f1-score: 0.8489 - val_loss: 0.8145 - val_iou_score: 0.7078 - val_f1-score: 0.8132
# Epoch 80/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7928 - iou_score: 0.7875 - f1-score: 0.8719 - val_loss: 0.8109 - val_iou_score: 0.7238 - val_f1-score: 0.8218
# Epoch 81/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7943 - iou_score: 0.7860 - f1-score: 0.8707 - val_loss: 0.8123 - val_iou_score: 0.7129 - val_f1-score: 0.8217
# Epoch 82/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7904 - iou_score: 0.8022 - f1-score: 0.8840 - val_loss: 0.8142 - val_iou_score: 0.7138 - val_f1-score: 0.8099
# Epoch 83/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7930 - iou_score: 0.7886 - f1-score: 0.8730 - val_loss: 0.8034 - val_iou_score: 0.7519 - val_f1-score: 0.8485
# Epoch 84/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7947 - iou_score: 0.7862 - f1-score: 0.8674 - val_loss: 0.8058 - val_iou_score: 0.7420 - val_f1-score: 0.8408
# Epoch 85/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7919 - iou_score: 0.7889 - f1-score: 0.8745 - val_loss: 0.8100 - val_iou_score: 0.7241 - val_f1-score: 0.8266
# Epoch 86/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7935 - iou_score: 0.7886 - f1-score: 0.8705 - val_loss: 0.8021 - val_iou_score: 0.7567 - val_f1-score: 0.8506
# Epoch 87/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7931 - iou_score: 0.7876 - f1-score: 0.8682 - val_loss: 0.8023 - val_iou_score: 0.7571 - val_f1-score: 0.8502
# Epoch 88/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7904 - iou_score: 0.7857 - f1-score: 0.8616 - val_loss: 0.8075 - val_iou_score: 0.7363 - val_f1-score: 0.8354
# Epoch 89/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7941 - iou_score: 0.7761 - f1-score: 0.8588 - val_loss: 0.8081 - val_iou_score: 0.7357 - val_f1-score: 0.8323
# Epoch 90/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7931 - iou_score: 0.7936 - f1-score: 0.8773 - val_loss: 0.8015 - val_iou_score: 0.7620 - val_f1-score: 0.8549
# Epoch 91/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7906 - iou_score: 0.7992 - f1-score: 0.8814 - val_loss: 0.8109 - val_iou_score: 0.7291 - val_f1-score: 0.8268
# Epoch 92/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7917 - iou_score: 0.7814 - f1-score: 0.8660 - val_loss: 0.8061 - val_iou_score: 0.7401 - val_f1-score: 0.8376
# Epoch 93/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7898 - iou_score: 0.8037 - f1-score: 0.8848 - val_loss: 0.8135 - val_iou_score: 0.7126 - val_f1-score: 0.8174
# Epoch 94/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7925 - iou_score: 0.7894 - f1-score: 0.8726 - val_loss: 0.7966 - val_iou_score: 0.7823 - val_f1-score: 0.8685
# Epoch 95/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7874 - iou_score: 0.8143 - f1-score: 0.8918 - val_loss: 0.7999 - val_iou_score: 0.7669 - val_f1-score: 0.8582
# Epoch 96/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7908 - iou_score: 0.7893 - f1-score: 0.8702 - val_loss: 0.8022 - val_iou_score: 0.7579 - val_f1-score: 0.8514
# Epoch 97/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7898 - iou_score: 0.7811 - f1-score: 0.8578 - val_loss: 0.8001 - val_iou_score: 0.7633 - val_f1-score: 0.8554
# Epoch 98/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7903 - iou_score: 0.7760 - f1-score: 0.8544 - val_loss: 0.8079 - val_iou_score: 0.7384 - val_f1-score: 0.8350
# Epoch 99/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7901 - iou_score: 0.7966 - f1-score: 0.8787 - val_loss: 0.8089 - val_iou_score: 0.7305 - val_f1-score: 0.8314
# Epoch 100/100
# 57/57 [==============================] - 14s 245ms/sample - loss: 0.7886 - iou_score: 0.7890 - f1-score: 0.8642 - val_loss: 0.8036 - val_iou_score: 0.7538 - val_f1-score: 0.8445

# %%
#Save model for future use
model.save('3D_model_vgg16_100epochs.h5')

# %%
###
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
#Load the pretrained model for testing and predictions. 
from tensorflow.keras.models import load_model
my_model = load_model('3D_model_vgg16_100epochs.h5', compile=False)
#If you load a different model do not forget to preprocess accordingly.

# %%
#Predict on the test data
y_pred=my_model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=4)
y_test_argmax = np.argmax(y_test, axis=4)

# %%
print(y_pred_argmax.shape)
print(y_test_argmax.shape)
print(np.unique(y_pred_argmax))
# Out:
# (7, 64, 64, 64)
# (7, 64, 64, 64)
# [0 2 3]

# %%
#Using built in keras function for IoU
#Only works on TF > 2.0
from tensorflow.keras.metrics import MeanIoU
n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.004124853

# %%
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]

test_img_input=np.expand_dims(test_img, 0)
test_img_input1 = preprocess_input(test_img_input)

test_pred1 = my_model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=4)[0,:,:,:]
print(test_prediction1.shape)
# Out:
# (64, 64, 64)

# %%
ground_truth_argmax = np.argmax(ground_truth, axis=3)
print(test_img.shape)
# Out:
# (64, 64, 64, 3)

# %%
#Plot individual slices from test predictions for verification
slice = 14
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[slice,:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth_argmax[slice,:,:])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1[slice,:,:])
plt.show()

# %% [markdown]
# Now segment the full volume using the trained model.

# %%
#Break the large image (volume) into patches of same size as the training images (patches)
large_image = io.imread('/content/sandstone_data_for_ML/data_for_3D_Unet/448_images_512x512.tif')
patches = patchify(large_image, (64, 64, 64), step=64)  #Step=256 for 256 patches means no overlap
print(large_image.shape)
print(patches.shape)
# Out:
# (448, 512, 512)
# (7, 8, 8, 64, 64, 64)

# %%
# Predict each 3D patch   
predicted_patches = []
for i in range(patches.shape[0]):
  for j in range(patches.shape[1]):
    for k in range(patches.shape[2]):
      #print(i,j,k)
      single_patch = patches[i,j,k, :,:,:]
      single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
      single_patch_3ch_input = preprocess_input(np.expand_dims(single_patch_3ch, axis=0))
      single_patch_prediction = my_model.predict(single_patch_3ch_input)
      single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=4)[0,:,:,:]
      predicted_patches.append(single_patch_prediction_argmax)

# %%
#Convert list to numpy array
predicted_patches = np.array(predicted_patches)
print(predicted_patches.shape)
# Out:
# (448, 64, 64, 64)

# %%
#Reshape to the shape we had after patchifying
predicted_patches_reshaped = np.reshape(predicted_patches, 
                                        (patches.shape[0], patches.shape[1], patches.shape[2],
                                         patches.shape[3], patches.shape[4], patches.shape[5]) )
print(predicted_patches_reshaped.shape)
# Out:
# (7, 8, 8, 64, 64, 64)

# %%
#Repach individual patches into the orginal volume shape
reconstructed_image = unpatchify(predicted_patches_reshaped, large_image.shape)
print(reconstructed_image.shape)
# Out:
# (448, 512, 512)

# %%
fig,ax=plt.subplots(ncols=2,figsize=(10,15))
ax[0].imshow(reconstructed_image[0,:,:],cmap='gray')
ax[0].set_title('Predicted Image')
ax[1].imshow(large_image[0,:,:],cmap='gray')
ax[1].set_title('Real Image')
# Out:
# Text(0.5, 1.0, 'Real Image')

# %%
print(reconstructed_image.dtype)
# Out:
# int64

# %%
#Convert to uint8 so we can open image in most image viewing software packages
reconstructed_image=reconstructed_image.astype(np.uint8)
print(reconstructed_image.dtype)
# Out:
# uint8

# %%
#Now save it as segmented volume.
from tifffile import imsave
imsave('segmented.tif', reconstructed_image)

# %%
#If you would like to save the volume as multichannel dataset....

# %%
print(np.unique(reconstructed_image))
# Out:
# [0 1 2 3]

# %%
#Seperate each channel/segment to be combined as multiple channels.
num_segments=4
segm0 = (reconstructed_image == 0)
segm1 = (reconstructed_image == 1)
segm2 = (reconstructed_image == 2)
segm3 = (reconstructed_image == 3)

final = np.empty((reconstructed_image.shape[0], reconstructed_image.shape[1], reconstructed_image.shape[2], num_segments))
final[:,:,:,0] = segm0
final[:,:,:,1] = segm1
final[:,:,:,2] = segm2
final[:,:,:,3] = segm3

# %%
#Use APEER OMETIFF library to read and write multidimensional images
# !pip install apeer-ometiff-library
# Out:
# Collecting apeer-ometiff-library
#   Downloading https://files.pythonhosted.org/packages/ff/1a/338fc19c9be9c1f911fbbf9cb1315b0d98841936498e11c6f105b397e2b7/apeer_ometiff_library-1.7.2-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from apeer-ometiff-library) (1.19.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (from apeer-ometiff-library) (2021.4.8)
# Installing collected packages: apeer-ometiff-library
# Successfully installed apeer-ometiff-library-1.7.2

# %%
from apeer_ometiff_library import io

# %%
# Expand image array to 5D of order (T, Z, C, X, Y)
# This is the convention for OMETIFF format as written by APEER library
final = np.expand_dims(final, axis=0)
final=np.swapaxes(final, 2, 4)

final = final.astype(np.int8)

# %%
print("Shape of the segmented volume is: T, Z, C, X, Y ", final.shape)
print(final.dtype)
# Out:
# Shape of the segmented volume is: T, Z, C, X, Y  (1, 448, 4, 512, 512)
# int8

# %%
# Write dataset as multi-dimensional OMETIFF *image*
io.write_ometiff("segmented_multi_channel.ome.tiff", final)
